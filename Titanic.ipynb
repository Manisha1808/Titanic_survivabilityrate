# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("Titanic-Dataset.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
df.tail(10)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 881          882         0       3                        Markun, Mr. Johann
# 882          883         0       3              Dahlberg, Miss. Gerda Ulrika
# 883          884         0       2             Banfield, Mr. Frederick James
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df['Sex'].value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
df['Age'].value_counts()
# Out:
# Age
# 24.00    30
# 22.00    27
# 18.00    26
# 19.00    25
# 28.00    25
#          ..
# 36.50     1
# 55.50     1
# 0.92      1
# 23.50     1
# 74.00     1
# Name: count, Length: 88, dtype: int64

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.shape
# Out:
# (183, 12)

# %%
df.sort_values(['Sex'])
# Out:
#      PassengerId  Survived  Pclass  \
# 383          384         1       1
# 218          219         1       1
# 609          610         1       1
# 216          217         1       3
# 215          216         1       1
# ..           ...       ...     ...
# 371          372         0       3
# 372          373         0       3
# 373          374         0       1
# 360          361         0       3
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 383  Holverson, Mrs. Alexander Oskar (Mary Aline To...  female  35.0      1
# 218                              Bazzani, Miss. Albina  female  32.0      0
# 609                          Shutes, Miss. Elizabeth W  female  40.0      0
# 216                             Honkanen, Miss. Eliina  female  27.0      0
# 215                            Newell, Miss. Madeleine  female  31.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
df[['Name','Sex','Age']]
# Out:
#                                                   Name     Sex   Age
# 0                              Braund, Mr. Owen Harris    male  22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                               Heikkinen, Miss. Laina  female  26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                             Allen, Mr. William Henry    male  35.0
# ..                                                 ...     ...   ...
# 886                              Montvila, Rev. Juozas    male  27.0
# 887                       Graham, Miss. Margaret Edith  female  19.0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN
# 889                              Behr, Mr. Karl Howell    male  26.0
# 890                                Dooley, Mr. Patrick    male  32.0
#
# [891 rows x 3 columns]

# %%
df.dropna(inplace=True)

# %%
#make pivot table
df_pivot=df.pivot(index='Sex',columns='Name' ,values='Survived')
df_pivot.T
# Out:
# Sex                                              female  male
# Name
# Allen, Miss. Elisabeth Walton                       1.0   NaN
# Allison, Master. Hudson Trevor                      NaN   1.0
# Allison, Miss. Helen Loraine                        0.0   NaN
# Allison, Mrs. Hudson J C (Bessie Waldo Daniels)     0.0   NaN
# Anderson, Mr. Harry                                 NaN   1.0
# ...                                                 ...   ...
# White, Mr. Percival Wayland                         NaN   0.0
# White, Mr. Richard Frasar                           NaN   0.0
# Wick, Miss. Mary Natalie                            1.0   NaN
# Widener, Mr. Harry Elkins                           NaN   0.0
# Young, Miss. Marie Grice                            1.0   NaN
#
# [183 rows x 2 columns]

# %%
pivot=df.pivot_table(index='Sex',values=['Ticket','Fare'],  aggfunc="count")
pivot
# Out:
#         Fare  Ticket
# Sex
# female    88      88
# male      95      95

# %%
pivot.plot(kind="bar")
plt.title('Distribution of fare and tickett')
plt.xlabel('Gender')
plt.ylabel('Ticket & Fare count')
plt.show()

# %%
pivot2=df.pivot_table(index=['Sex','Age'],values='Ticket',  aggfunc="count")
pivot2
# Out:
#              Ticket
# Sex    Age
# female 2.0        2
#        4.0        2
#        14.0       1
#        15.0       1
#        16.0       3
# ...             ...
# male   64.0       1
#        65.0       2
#        70.0       1
#        71.0       1
#        80.0       1
#
# [95 rows x 1 columns]

# %%
pivot2=df.pivot_table(index=['Sex','Age'],values=['Ticket','Fare'],  aggfunc="sum")
pivot2.T
# Out:
# Sex           female                                                         \
# Age             2.0            4.0     14.0      15.0                  16.0
# Fare        162.0125           55.7   120.0  211.3375              183.8792
# Ticket  347054113781  PP 9549230136  113760     24160  111361110152PC 17592
#
# Sex                                                              \
# Age              17.0                    18.0              19.0
# Fare            165.9                  569.55          147.3625
# Ticket  PC 1775817474  PC 17608110413PC 17757  1175211967112053
#
# Sex                                       ...        male                     \
# Age              21.0               22.0  ...        56.0        58.0   60.0
# Fare         340.3333              171.1  ...     66.1958     142.975   79.2
# Ticket  13502PC 17608  11377611350513568  ...  1776413213  1177135273  13567
#
# Sex
# Age            61.0    62.0   64.0         65.0       70.0      71.0   80.0
# ...
